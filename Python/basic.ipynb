# %% [markdown]
# ## Basic Syntax Rule in Python:-

# %%
## Case Sensitivity:- Python is care sensitive
## Example:-
name="dishu"
Name="dikshant"
print(name)
print(Name)
# Out:
# dishu
# dikshant

# %%
## Indentation:- Python use indentation to define bloacks of code. Consistent use of space or a tab is required.
a=32
if a>30:
    print(a)
# Out:
# 32

# %%
## Single Line Comment:-
print("Hello World")
# Out:
# Hello World

# %%
## Line Continuation:-'\'
## use a backslash(\) to continua a statement to the next line.
total=1+2+3+4\
+5+6
print(total)
# Out:
# 21

# %%
## Multiple statement on a single line:-
x=5;b=10;z=x+b
print(z)
# Out:
# 15

# %% [markdown]
# ## Understand Semmatics in Python:- -->

# %%
### 1) variable assignment:-
age=10 ## age is a integer (int)
name="dikshant" ## name ia a string(str)

# %%
# 2) type Inferences:-
# integer type:-                      # string type:-
variable=10                              varible="disihu"
print(type(variable))                    print(type(varible))

# %%
# 3) Name Error:-
a=b
# Error message:- b is not define

# %%
# Code examples of indentation :-
if True:
    print("correct Indentation ")
    if False:
       print("This not print")
    print("this will print")
print("out side the if block")
# Out:
# correct Indentation
# this will print
# out side the if block

# %% [markdown]
# ## Variable : variables are fundamental elements in programing used to store data that can be referened and mainpulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit decloration to resweve memory space. the dicloration happyens automaticaly when you assign a value to a variable.
#
#
# ## Outline:-
# 1. Introduction to variables -> a=10
# 2. Declaring and Assigning variables
# 3. Naming Conventions
# 4. Understanding Variable Types
# 5.Type Checking and Conversion
# 6. Dynamic Typing
# 7. Practical Example and Common Errors

# %%
## Declaring and Assigning variables ->
age =19
height=5.8
name="dikshant"
is_student=True
print("age:",age)
print("height:",height)
print("Name:",name)
# Out:
# age: 19
# height: 5.8
# Name: dikshant

# %%
## Naming Conventions:-
# 1. Variable names should be meaningful and descriptive.
# 2. Variable names should start with a letter or underscore (_).
# 3. Variable names should not contain any special characters or spaces.
# 4. Variable names should not start or end with a number.
# 5. Variable names should not be keywords or built-in functions.
# 6. Variable names should be lowercase, separated by underscores if necessary.

# %%
# Valid variable name :-
first_name ="dishu"
last_name ="Dikshant"

# Invalid variable name :-
2age=52
first-name="dikshant"
@name="dishu"

# %%
# Case Sensitive:
name="dishu"
Name="diskhat"

# %% [markdown]
# ## Understanding Variables types :-
# Python is dynamically typed , typed of a variable is determined  at runtime .
# 1. Integer Type (int)
# 2. Float Type (float)
# 3. String Type (str)
# 4. Boolean Type (bool)
# 5. List Type (list)
# 6. Tuple Type (tuple)

# %%
age=19 #int
height=5.7 #float 
name="dishu" #string
is_student = True #boolean
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
DataTypes:

# %% [markdown]
# Outlines:
# 1) Introduction of Datatype
# 2) Important of DataTypes in programming
# 3) Basic Datatype:
#   -> Integers (int)
#   -> float (1.2)
#   -> string (dishu)
#   -> Bool (True,False)
# 4) Advance Datatype:
#   -> list
#   -> Tuples
#   -> sets
#   -> Dictionaries
# 5) Types Conversion
# 6) Practical Example

# %%
1 Definition of DataTypes: # type: ignore
    Data types are a classification of data which tell the compiler or interpreter how the programmer intends to use the data.#type: ignore
    They determine the type of operation that can be performed on the data, the values that tha data can take and the amount of memory needs to store the data # type: ignore

# %% [markdown]
# 2 Importance of DataType in Programing:
# ->Data types ensure that data is stored in an efficient way.
# -> They help in performing correct operations on data.
# -> Proper use of data type can prevent errors and bugs in the programing.

# %%
## -> Integer (int) :   # type: ignore
age=20
print(type(age))
# Out:
# <class 'int'>

# %%
## Float: (1.30)
height=2.3
print(type(height))
# Out:
# <class 'float'>

# %%
## Boolean :(True,False)
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
## Common errors:-
result="hello" + 23
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 ## Common errors:-
# ----> 2 result="hello" + 23
#
# TypeError: can only concatenate str (not "int") to str

# %%
result="hello" + str(23)
print(type(result))
# Out:
# <class 'str'>

# %% [markdown]
#  Operators:-
#  1) Introduction of operators
#  2) Arithmetic operators
#     ->Addition [+]
#     ->Subtraction[-]
#     ->Multiplication[*]
#     ->Division[/]
#     ->Floor division[//]
#     ->Modular[%]
#     ->Exponentiation[**]
# 3) Comparison operators:
#     ->Equal to [=]
#     ->not equal to [!=]
#     ->Greater than[>=]
#     ->less than[=<]
# 4) Logical operators:-
#     ->AND
#     ->or
#     ->not
# 5) practical example and common errors:

# %%
## Arithmetic operation:
a=10
b=8
add_result=a+b
sub_result=a-b
mult_result=a*b
div_result=a/b
floor_div=a//b
modulus_result=a%b
exponent_result=a**b
print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(modulus_result)
print(exponent_result)
# Out:
# 18
# 2
# 80
# 1.25
# 2
# 100000000

# %%
## Comparison operators:
# Equal to [=]
a=10
b=10
result=(a==b)
print(result)
# Out:
# True

# %%
# Not Equal to : [!=]
str1="dishu"
str2="dikshant"
str1!=str2

str3="ram"
str5="Ram"
str3!=str5
# Out:
# True

# %%
#Greater than: [>]
num1=45
num2=55
num1>num2
# Out:
# False

# %%
# less then:[<]
num1=45
num2=55
num1<num2
# Out:
# True

# %%
# Greater than or equal to : [>=]
num1=45
num2=55
num1>=num2
# Out:
# False

# %%
# less than or equal to :[<=]
num1=45
num2=55
num1<=num2
# Out:
# True

# %%
# Logical operators :- And,not,or
# And:
x=True
y=False
result=x and y
print(result)
# Out:
# False

# %%
   # OR
x=False
y=False
result=x or y
print(result)
# Out:
# False

# %%
x=True
y=False
result=x or y
print(result)
# Out:
# True

# %%
# Not:
x=True
not x
# Out:
# False

# %%
x=False
not x
# Out:
# True

# %% [markdown]
# Simple calculator

# %%
a=float(input("Enter the first number :"))
b=float(input("Enter the second number :"))
add_result=a+b
sub_result=a-b
mult_result=a*b
div_result=a/b
floor_div=a//b
modulus_result=a%b
exponent_result=a**b
print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(modulus_result)
print(exponent_result)
# Out:
# 110.0
# -2.0
# 3024.0
# 0.9642857142857143
# 54.0
# 1.0328816219251025e+97
